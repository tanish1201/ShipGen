# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("E:/sem5/apl302product/computational_project/reduced_data.csv")

# %%
df.head()
# Out:
#         PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0 -11.778852 -5.963981  2.708248  0.291570 -8.006616 -0.704716 -1.576061
# 1  -8.364062 -5.211114  2.624651  2.394817 -5.990686  3.183806  2.804452
# 2 -14.688830  0.935685  2.557508  2.727295 -4.719920  0.800718  0.966228
# 3  -1.910175 -3.550928  1.806465  1.173408 -4.542943  3.716949  1.656472
# 4  -4.126756 -0.388126  3.222836 -5.845613 -2.105691  0.929160  0.729523
#
#         PCA8      PCA9     PCA10  ...     PCA24     PCA25     PCA26     PCA27  \
# 0  -0.569835  1.145670 -3.903905  ... -0.192099  0.841043 -0.677818 -1.100252
# 1  -9.446988  1.895687 -3.324126  ...  0.954720  0.141486 -0.115227 -0.767748
# 2  -4.047640  1.352594 -2.591009  ...  0.107462  0.234375 -0.328368 -0.957779
# 3 -11.128732  1.854527 -3.212603  ...  0.538462 -0.680553 -0.698616 -0.838881
# 4  -0.887728  0.618052 -1.056827  ... -0.314542  0.279962 -0.386722 -0.538391
#
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
# Select features (all PCA columns in this case)
X = df.iloc[:, :]

# Apply K-Means clustering (choosing 3 clusters as an example; adjust as needed)
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)

# Add the cluster labels to the data
df['Cluster'] = kmeans.labels_

# Reduce dimensions for visualization (2D)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Plot the data in 2D with clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans.labels_, cmap='viridis', s=50, marker='o')
plt.title("2D Visualization of Clusters with K-Means")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.colorbar(label="Cluster Label")
plt.show()
# Out:
# C:\Users\91914\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.manifold import TSNE

# %%
# Apply t-SNE for dimensionality reduction to 2D
tsne = TSNE(n_components=2, random_state=0)
X_tsne = tsne.fit_transform(X)

# Plot the data in 2D with clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=kmeans.labels_, cmap='viridis', s=50, marker='o')
plt.title("2D Visualization of Clusters with t-SNE")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.colorbar(label="Cluster Label")
plt.show()

# %%
# Select features (all PCA columns in this case)
X = df.iloc[:, :]

# Apply K-Means clustering (choosing 3 clusters as an example; adjust as needed)
kmeans = KMeans(n_clusters=6, random_state=0)
kmeans.fit(X)

# Add the cluster labels to the data
df['Cluster'] = kmeans.labels_

# Reduce dimensions for visualization (2D)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Plot the data in 2D with clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans.labels_, cmap='viridis', s=50, marker='o')
plt.title("2D Visualization of Clusters with K-Means")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.colorbar(label="Cluster Label")
plt.show()
# Out:
# C:\Users\91914\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Select features
X = df.iloc[:, :]

# Determine the optimal number of clusters using the elbow method
inertia = []
cluster_range = range(1, 11)  # Testing from 1 to 10 clusters

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)  # Inertia is the WCSS metric

# Plot the elbow graph
plt.figure(figsize=(8, 6))
plt.plot(cluster_range, inertia, marker='o', linestyle='-')
plt.title("Elbow Method for Optimal Clusters")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia (WCSS)")
plt.xticks(cluster_range)
plt.show()
# Out:
# C:\Users\91914\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91914\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# Choose the optimal cluster number based on the elbow graph (let's say it's 3 here)
optimal_clusters = 4
kmeans = KMeans(n_clusters=optimal_clusters, random_state=0)
kmeans.fit(X)

# Add the optimal cluster labels to the data
df['Cluster'] = kmeans.labels_

# Reduce dimensions for visualization (2D)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Plot the data in 2D with clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans.labels_, cmap='viridis', s=50, marker='o')
plt.title(f"2D Visualization of Clusters with K-Means (k={optimal_clusters})")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.colorbar(label="Cluster Label")
plt.show()
# Out:
# C:\Users\91914\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
